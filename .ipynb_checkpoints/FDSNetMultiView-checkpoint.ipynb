# %%
# %cd /home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0
# Out:
# /home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0

# %%
# === Step 1: Imports ===
from mmdet3d.apis import init_model, inference_detector
from mmdet3d.registry import VISUALIZERS
from mmdet3d.utils import register_all_modules
register_all_modules()
# Out:
# /home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/mmdet3d/evaluation/functional/kitti_utils/eval.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def get_thresholds(scores: np.ndarray, num_gt, num_sample_pts=41):
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import mmcv
import os

# === Step 2: Config & Checkpoint Paths ===
config_file = '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/projects/BEVFusion/configs/bevfusion_lidar_voxel0075_second_secfpn_8xb4-cyclic-20e_nus-3d.py'
checkpoint_file = '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/checkpoints/bevfusion_lidar-cam_voxel0075_second_secfpn_8xb4-cyclic-20e_nus-3d-5239b1af.pth'

# %%
# === Step 3: Input sample ===
img_paths = [
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_BACK__1532402927637525.jpg',
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_BACK_LEFT__1532402927647423.jpg',
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_BACK_RIGHT__1532402927627893.jpg',
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_FRONT__1532402927612460.jpg',
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_FRONT_LEFT__1532402927604844.jpg',
    '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__CAM_FRONT_RIGHT__1532402927620339.jpg'

]
pcd_path = '/home/asaad/Documents/2024/FDSNet/mmdetection3d-1.2.0/data/nuscenes/n015-2018-07-24-11-22-45+0800__LIDAR_TOP__1532402927647951.pcd.bin'

# %%
# === Step 4: Initialize model ===
model = init_model(config_file, checkpoint_file, device='cuda:0')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/envs/FDSNet/lib/python3.8/site-packages/mmengine/utils/misc.py:77, in import_modules_from_strings(imports, allow_failed_imports)
#      76 try:
# ---> 77     imported_tmp = import_module(imp)
#      78 except ImportError:
#
# File ~/anaconda3/envs/FDSNet/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# ...
